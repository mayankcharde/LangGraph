# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_openai import ChatOpenAI

# %%
# THIS ADD MESSAGE IS USED FOR ADDING THE MESSAGES TO THE STATE AUTOMATICALLY WHENEVER WE UPDATE THE STATE
from langgraph.graph.message import add_messages

class ChatState(TypedDict):

    messages: Annotated[list[BaseMessage], add_messages]

# %%
llm = ChatOpenAI()

def chat_node(state: ChatState):
    
    # take user query from state
    messages  = state['messages']
    
    # swnd to llm
    response = llm.invoke(messages)
    
    # retrun the response 
    return {'messages': [response]}
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 llm = ChatOpenAI()
#       3 def chat_node(state: ChatState):
#       4
#       5     # take user query from state
#       6     messages  = state['messages']
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_openai\chat_models\base.py:744, in BaseChatOpenAI.validate_environment(self)
#     737         self.http_client = httpx.Client(
#     738             proxy=self.openai_proxy, verify=global_ssl_context
#     739         )
#     740     sync_specific = {
#     741         "http_client": self.http_client
#     742         or _get_default_httpx_client(self.openai_api_base, self.request_timeout)
#     743     }
# --> 744     self.root_client = openai.OpenAI(**client_params, **sync_specific)  # type: ignore[arg-type]
#     745     self.client = self.root_client.chat.completions
#     746 if not self.async_client:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_client.py:130, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128     api_key = os.environ.get("OPENAI_API_KEY")
#     129 if api_key is None:
# --> 130     raise OpenAIError(
#     131         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     132     )
#     133 self.api_key = api_key
#     135 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
graph = StateGraph(ChatState)

# add nodes 
graph.add_node('chat_node', chat_node)

graph.add_edge(START, 'chat_node')
graph.add_edge('chat_node', END)

chatbot = graph.compile()

chatbot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 graph = StateGraph(ChatState)
#       3 # add nodes
# ----> 4 graph.add_node('chat_node', chat_node)
#       6 graph.add_edge(START, 'chat_node')
#       7 graph.add_edge('chat_node', END)
#
# NameError: name 'chat_node' is not defined

# %%
initial_state = {
    'messages': [HumanMessage(content='What is the capital of india')]
}

chatbot.invoke(initial_state)['messages'][-1].content
